# %%
import pandas as pd

# %% [markdown]
# ## Setup

# %%
df1 = pd.DataFrame.from_dict({
    'SensorID': [1,2,3,4,5],
    'Place': ['LHR','LGA','STA','LUT','SEN'],
    'Owner': ['BAA','GIP','MAG','Luton LA','Stobart']
})

df2 = pd.DataFrame.from_dict({
    'SensorID': [1,1,3,4,6],
    'Parameter': ['Temperature','Humidity','Temperature','Temperature','Humidity'],
    'Value': [5, 0.15, 7, 7, 0.18]
})

# %%
df1
# Out:
#    SensorID Place     Owner
# 0         1   LHR       BAA
# 1         2   LGA       GIP
# 2         3   STA       MAG
# 3         4   LUT  Luton LA
# 4         5   SEN   Stobart

# %%
df2
# Out:
#    SensorID    Parameter  Value
# 0         1  Temperature   5.00
# 1         1     Humidity   0.15
# 2         3  Temperature   7.00
# 3         4  Temperature   7.00
# 4         6     Humidity   0.18

# %% [markdown]
# ## Join/Merge

# %% [markdown]
# ### Simple Merge

# %%
pd.merge(df1, df2, on='SensorID')
# Out:
#    SensorID Place     Owner    Parameter  Value
# 0         1   LHR       BAA  Temperature   5.00
# 1         1   LHR       BAA     Humidity   0.15
# 2         3   STA       MAG  Temperature   7.00
# 3         4   LUT  Luton LA  Temperature   7.00

# %% [markdown]
# ### Inner Join

# %%
pd.merge(df1, df2, on='SensorID', how='inner')
# Out:
#    SensorID Place     Owner    Parameter  Value
# 0         1   LHR       BAA  Temperature   5.00
# 1         1   LHR       BAA     Humidity   0.15
# 2         3   STA       MAG  Temperature   7.00
# 3         4   LUT  Luton LA  Temperature   7.00

# %%
df2tmp = df2.copy()
df2tmp.rename(columns={'SensorID':'SensorKey'}, inplace=True)
pd.merge(df1, df2tmp, left_on='SensorID', right_on='SensorKey', how='inner')
# Out:
#    SensorID Place     Owner  SensorKey    Parameter  Value
# 0         1   LHR       BAA          1  Temperature   5.00
# 1         1   LHR       BAA          1     Humidity   0.15
# 2         3   STA       MAG          3  Temperature   7.00
# 3         4   LUT  Luton LA          4  Temperature   7.00

# %% [markdown]
# ### Outer Join

# %%
pd.merge(df1, df2, on='SensorID', how='outer')
# Out:
#    SensorID Place     Owner    Parameter  Value
# 0         1   LHR       BAA  Temperature   5.00
# 1         1   LHR       BAA     Humidity   0.15
# 2         2   LGA       GIP          NaN    NaN
# 3         3   STA       MAG  Temperature   7.00
# 4         4   LUT  Luton LA  Temperature   7.00
# 5         5   SEN   Stobart          NaN    NaN
# 6         6   NaN       NaN     Humidity   0.18

# %% [markdown]
# ### Left Join

# %%
pd.merge(df1, df2, on='SensorID', how='left')
# Out:
#    SensorID Place     Owner    Parameter  Value
# 0         1   LHR       BAA  Temperature   5.00
# 1         1   LHR       BAA     Humidity   0.15
# 2         2   LGA       GIP          NaN    NaN
# 3         3   STA       MAG  Temperature   7.00
# 4         4   LUT  Luton LA  Temperature   7.00
# 5         5   SEN   Stobart          NaN    NaN

# %% [markdown]
# ### Right Join

# %%
pd.merge(df1, df2, on='SensorID', how='right')
# Out:
#    SensorID Place     Owner    Parameter  Value
# 0         1   LHR       BAA  Temperature   5.00
# 1         1   LHR       BAA     Humidity   0.15
# 2         3   STA       MAG  Temperature   7.00
# 3         4   LUT  Luton LA  Temperature   7.00
# 4         6   NaN       NaN     Humidity   0.18

# %% [markdown]
# ## Append & Concat

# %%
df3 = pd.DataFrame.from_dict({
    'SensorID': [2,3,8,9,10],
    'Place': ['STA','LUT','BHX','MAN','INV'],
    'Owner': ['BAA','Luton LA','???','???','???']
})

df4 = pd.DataFrame.from_dict({
    'SensorID': [1,2,3,4,5],
    'Parameter': ['Accuracy','Accuracy','Accuracy','Accuracy','Accuracy'],
    'Value': [0.25, 0.15, 0.25, 0.25, 0.15]
})

# %%
pd.concat([df1, df3])
# Out:
#    SensorID Place     Owner
# 0         1   LHR       BAA
# 1         2   LGA       GIP
# 2         3   STA       MAG
# 3         4   LUT  Luton LA
# 4         5   SEN   Stobart
# 0         2   STA       BAA
# 1         3   LUT       GIP
# 2         8   BHX       ???
# 3         9   MAN       ???
# 4        10   INV       ???

# %%
pd.concat([df1, df3], ignore_index=True)
# Out:
#    SensorID Place     Owner
# 0         1   LHR       BAA
# 1         2   LGA       GIP
# 2         3   STA       MAG
# 3         4   LUT  Luton LA
# 4         5   SEN   Stobart
# 5         2   STA       BAA
# 6         3   LUT       GIP
# 7         8   BHX       ???
# 8         9   MAN       ???
# 9        10   INV       ???

# %%
df1tmp = df1.set_index('SensorID')
df3tmp = df3.set_index('SensorID')
pd.concat([df1tmp, df3tmp], join='inner')
# Out:
#          Place     Owner
# SensorID
# 1          LHR       BAA
# 2          LGA       GIP
# 3          STA       MAG
# 4          LUT  Luton LA
# 5          SEN   Stobart
# 2          STA       BAA
# 3          LUT       GIP
# 8          BHX       ???
# 9          MAN       ???
# 10         INV       ???

# %%
pd.concat([df2, df4], axis=1)
# Out:
#    SensorID    Parameter  Value  SensorID Parameter  Value
# 0         1  Temperature   5.00         1  Accuracy   0.25
# 1         1     Humidity   0.15         2  Accuracy   0.15
# 2         3  Temperature   7.00         3  Accuracy   0.25
# 3         4  Temperature   7.00         4  Accuracy   0.25
# 4         6     Humidity   0.18         5  Accuracy   0.15

# %%
df2tmp = df2.set_index('SensorID')
df4tmp = df4.set_index('SensorID')
pd.concat([df2tmp, df4tmp], axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-a0b058cdb865> in <module>
#       1 df2tmp = df2.set_index('SensorID')
#       2 df4tmp = df4.set_index('SensorID')
# ----> 3 pd.concat([df2tmp, df4tmp], axis=1)
#
# /opt/conda/envs/sds2020/lib/python3.7/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     285     )
#     286
# --> 287     return op.get_result()
#     288
#     289
#
# /opt/conda/envs/sds2020/lib/python3.7/site-packages/pandas/core/reshape/concat.py in get_result(self)
#     501
#     502             new_data = concatenate_block_managers(
# --> 503                 mgrs_indexers, self.new_axes, concat_axis=self.bm_axis, copy=self.copy,
#     504             )
#     505             if not self.copy:
#
# /opt/conda/envs/sds2020/lib/python3.7/site-packages/pandas/core/internals/concat.py in concatenate_block_managers(mgrs_indexers, axes, concat_axis, copy)
#      82         blocks.append(b)
#      83
# ---> 84     return BlockManager(blocks, axes)
#      85
#      86
#
# /opt/conda/envs/sds2020/lib/python3.7/site-packages/pandas/core/internals/managers.py in __init__(self, blocks, axes, do_integrity_check)
#     147
#     148         if do_integrity_check:
# --> 149             self._verify_integrity()
#     150
#     151         # Populate known_consolidate, blknos, and blklocs lazily
#
# /opt/conda/envs/sds2020/lib/python3.7/site-packages/pandas/core/internals/managers.py in _verify_integrity(self)
#     324         for block in self.blocks:
#     325             if block.shape[1:] != mgr_shape[1:]:
# --> 326                 raise construction_error(tot_items, block.shape[1:], self.axes)
#     327         if len(self.items) != tot_items:
#     328             raise AssertionError(
#
# ValueError: Shape of passed values is (9, 4), indices imply (7, 4)

# %%
df2tmp
# Out:
#             Parameter  Value
# SensorID
# 1         Temperature   5.00
# 1            Humidity   0.15
# 3         Temperature   7.00
# 4         Temperature   7.00
# 6            Humidity   0.18

# %%
df4tmp
# Out:
#          Parameter  Value
# SensorID
# 1         Accuracy   0.25
# 2         Accuracy   0.15
# 3         Accuracy   0.25
# 4         Accuracy   0.25
# 5         Accuracy   0.15

# %%
df2tmp.join(df4tmp, rsuffix='_r')
# Out:
#             Parameter  Value Parameter_r  Value_r
# SensorID
# 1         Temperature   5.00    Accuracy     0.25
# 1            Humidity   0.15    Accuracy     0.25
# 3         Temperature   7.00    Accuracy     0.25
# 4         Temperature   7.00    Accuracy     0.25
# 6            Humidity   0.18         NaN      NaN

# %%
df2.join(df4, rsuffix='_r')
# Out:
#    SensorID    Parameter  Value  SensorID_r Parameter_r  Value_r
# 0         1  Temperature   5.00           1    Accuracy     0.25
# 1         1     Humidity   0.15           2    Accuracy     0.15
# 2         3  Temperature   7.00           3    Accuracy     0.25
# 3         4  Temperature   7.00           4    Accuracy     0.25
# 4         6     Humidity   0.18           5    Accuracy     0.15

# %% [markdown]
# ### Append

# %%
import numpy as np
to_append = []
for i in range(1,5):
    to_append.append({
        'SensorID':np.random.randint(low=1, high=6),
        'Parameter': np.random.choice(['Temperature','Humidity']),
        'Value': np.random.random()*5
    })

# %%
to_append = [
    {'SensorID': 5, 'Parameter': 'Humidity', 'Value': 0.45},
    {'SensorID': 5, 'Parameter': 'Humidity', 'Value': 0.31},
    {'SensorID': 4, 'Parameter': 'Temperature', 'Value': 2},
    {'SensorID': 3, 'Parameter': 'Temperature', 'Value': 3}]

# %%
df2.append(to_append)
# Out:
#    SensorID    Parameter  Value
# 0         1  Temperature   5.00
# 1         1     Humidity   0.15
# 2         3  Temperature   7.00
# 3         4  Temperature   7.00
# 4         6     Humidity   0.18
# 0         5     Humidity   0.45
# 1         5     Humidity   0.31
# 2         4  Temperature   2.00
# 3         3  Temperature   3.00

# %%
df2
# Out:
#    SensorID    Parameter  Value
# 0         1  Temperature   5.00
# 1         1     Humidity   0.15
# 2         3  Temperature   7.00
# 3         4  Temperature   7.00
# 4         6     Humidity   0.18
