# %% [markdown]
# <div style="float:left">
#     <h1 style="width:450px">Practical 4: Object-Oriented Programming</h1>
#     <h2 style="width:450px">Getting to grips with Packages, Classes &amp; Objects</h2>
# </div>
# <div style="float:right"><img width="100" src="https://github.com/jreades/i2p/raw/master/img/casa_logo.jpg" /></div>

# %% [markdown]
# <div style="border: dotted 1px rgb(156,121,26); padding: 10px; margin: 5px; background-color: rgb(255,236,184); color: rgb(156,121,26)"><i>Note</i>: You should <a href="https://github.com/jreades/i2p/raw/master/practicals/Practical-04-Objects.ipynb">download this notebook from GitHub</a> and then save it to your own copy of the repository. I'd suggest adding it (<tt>git add Practical-04-...</tt>) right away and then committing (<tt>git commit -m "Some message"</tt>). Do this again at the end of the class and you'll have a record of everything you did, then you can <tt>git push</tt> it to GitHub.</div>

# %% [markdown]
# ## Task 1
#
# Let's have a demonstration of how classes work and why they're useful in programming. Building on last week's 'volume of a sphere' question here's how we'd create and work with a 'shape' class in Python:

# %%
from math import pi

class shape(object): # Inherit from base class 
    def __init__(self, d: float):
        self.shape_type = 'None'
        self.dimension = d
        return 
    
    def volume(self):
        raise Exception("Unimplmented method error.")
    
    def diameter(self):
        raise Exception("Unimplmented method error.")
        
    def type(self):
        return(self.shape_type)
    
class cube(shape): # Inherit from shape 
    def __init__(self, d):
        self.shape_type = 'Cube'
        self.dimension = d
        return
    
    def volume(self):
        return self.dimension**3
    
    def diameter(self):
        return (self.dimension**2 + self.dimension**2)**(1/2)

class sphere(shape): # Inherit from shape 
    def __init__(self, d):
        self.shape_type = 'Sphere'
        self.dimension = d
        return
    
    def volume(self):
        return (4/3) * pi * self.dimension**3
    
    def diameter(self):
        return self.dimension*2

class pyramid(shape): # Inherit from shape
    
    has_mummies = True # This is for *all* regular pyramids
    
    def __init__(self, d):
        self.shape_type = 'Regular Pyramid'
        self.dimension = d
        return  

class t_pyramid(pyramid): # Inherit from pyramid (this is a triangular pyramid)
    
    has_mummies = False # This is for all triangular pyramids
    
    def __init__(self, d):
        self.shape_type = 'Triangular Pyramid'
        self.dimension = d
        return 
    
    def area(self):
        return (3**(1/2)/4) * self.dimension**2
    
    def height(self):
        # https://www.youtube.com/watch?v=ivF3ndmkMsE
        return (6**(1/2) * self.dimension/3)
    
    def volume(self):
        #  V = 1/3 * A * h
        return (1/3) * self.area() * self.height()

s = sphere(10)
print(s.type())
print("\tVolume is: {0:5.2f}".format(s.volume()))
print("\tDiameter is: {0:5.2f}".format(s.diameter()))
print("")

c = cube(10)
print(c.type())
print("\tVolume is: {0:5.2f}".format(c.volume()))
print("\tDiameter is: {0:5.2f}".format(c.diameter()))
print("")

p = t_pyramid(10)
print(p.type())
print("\tVolume is: {0:5.2f}".format(p.volume()))
if p.has_mummies is True:
    print("\tMummies? Aaaaaaaaagh!")
else:
    print("\tPhew, no mummies!")

# The error here is deliberate -- note that diameter
# is not implemented in either triangular pyramid, pyramid, 
# or shape, only for spheres.
print("\tDiameter is: {0:5.2f}".format(p.diameter()))
print("")
# Out:
# Sphere
# 	Volume is: 4188.79
# 	Diameter is: 20.00
#
# Cube
# 	Volume is: 1000.00
# 	Diameter is: 14.14
#
# Triangular Pyramid
# 	Volume is: 117.85
# 	Phew, no mummies!
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-4-69f3f9db8e40> in <module>
#      92 # is not implemented in either triangular pyramid, pyramid,
#      93 # or shape, only for spheres.
# ---> 94 print("\tDiameter is: {0:5.2f}".format(p.diameter()))
#      95 print("")
#
# <ipython-input-4-69f3f9db8e40> in diameter(self)
#      11
#      12     def diameter(self):
# ---> 13         raise Exception("Unimplmented method error.")
#      14
#      15     def type(self):
#
# Exception: Unimplmented method error.

# %% [markdown]
# **Have a really good think about how this kind of behaviour is useful!**
#
# ### Test Your Understanding
#
# Based on the above examples of classes and methods, I have two challenges for you to implement in the code below:
# 1. Try fully-implementing the *regular* pyramid class with a square base that we skipped over above!
# 2. Try adding an `area` method that returns the surface area of each shape and then add that information to the output below.

# %%
from math import pi

class shape(object): # Inherit from base class 
    def __init__(self, d: float):
        self.shape_type = 'None'
        self.dimension = d
        return 
    
    def volume(self):
        raise Exception("Unimplmented method error.")
    
    def diameter(self):
        raise Exception("Unimplmented method error.")
        
    def type(self):
        return(self.shape_type)
    
class cube(shape): # Inherit from shape 
    def __init__(self, d):
        self.shape_type = 'Cube'
        self.dimension = d
        return
    
    def volume(self):
        return self.dimension**3
    
    def diameter(self):
        return (self.dimension**2 + self.dimension**2)**(1/2)

class sphere(shape): # Inherit from shape 
    def __init__(self, d):
        self.shape_type = 'Sphere'
        self.dimension = d
        return
    
    def volume(self):
        return (4/3) * pi * self.dimension**3
    
    def diameter(self):
        return self.dimension*2

class pyramid(shape): # Inherit from shape
    
    has_mummies = True # This is for *all* regular pyramids
    
    def __init__(self, d):
        self.shape_type = 'Regular Pyramid'
        self.dimension = d
        return
    
    def area(self):
        # SA = base area + 4 * equilateral triangles as sqrt(3)/4 * a^2
        return self.base_area() + 4 * (3**(1/2)/4) * self.dimension**2
    
    def base_area(self):
        return self.dimension**2
    
    def height(self):
        # Should be Pythagorean theorem sqrt(x^2 + y^2) where y is half
        # the length of the edge
        return (self.dimension**2 - (self.dimension/2)**2)**(1/2)
    
    def volume(self):
        # V = l * w * h / 3
        return self.dimension * self.dimension * self.height() / 3

class t_pyramid(pyramid): # Inherit from pyramid (this is a triangular pyramid)
    
    has_mummies = False # This is for all triangular pyramids
    
    def __init__(self, d):
        self.shape_type = 'Triangular Pyramid'
        self.dimension = d
        return 
    
    def area(self):
        return (3**(1/2)/4) * self.dimension**2
    
    def height(self):
        # https://www.youtube.com/watch?v=ivF3ndmkMsE
        return (6**(1/2) * self.dimension/3)
    
    def volume(self):
        #  V = 1/3 * A * h
        return (1/3) * self.area() * self.height()

# How would you test these changes?
s = sphere(10)
print(s.type())
print("\tVolume is: {0:5.2f}".format(s.volume()))
print("\tDiameter is: {0:5.2f}".format(s.diameter()))
print("")

c = cube(10)
print(c.type())
print("\tVolume is: {0:5.2f}".format(c.volume()))
print("\tDiameter is: {0:5.2f}".format(c.diameter()))
print("")

p = t_pyramid(10)
print(p.type())
print("\tVolume is: {0:5.2f}".format(p.volume()))
print(f"\tHeight is: {p.height():5.2f}")
if p.has_mummies is True:
    print("\tMummies? Aaaaaaaaagh!")
else:
    print("\tPhew, no mummies!")
print("")

p2 = pyramid(14)
print(p2.type())
print(f"\tVolume is: {p2.volume():5.2f}")
print(f"\tHeight is: {p2.height():5.2f}")
if p2.has_mummies is True:
    print("\tMummies? Aaaaaaaaagh!")
else:
    print("\tPhew, no mummies!")
print("")

# Useful demonstration of how to find out if a method or attribute is
# associated with a particular object
if hasattr(p2,'base_area'):
    print(f"Shape of type '{p2.type()}' has attribute or method 'base_area'")
else:
    print(f"Shape of type '{p2.type()}' does *not* have attribute or method 'base_area'")
print("")
# Out:
# Sphere
# 	Volume is: 4188.79
# 	Diameter is: 20.00
#
# Cube
# 	Volume is: 1000.00
# 	Diameter is: 14.14
#
# Triangular Pyramid
# 	Volume is: 117.85
# 	Height is:  8.16
# 	Phew, no mummies!
#
# Regular Pyramid
# 	Volume is: 792.12
# 	Height is: 12.12
# 	Mummies? Aaaaaaaaagh!
#
# Shape of type'Regular Pyramid' has attribute or method 'base_area'
